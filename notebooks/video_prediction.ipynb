# %% [markdown]
# # Video Detection
#
# The final helmet detection model is now tested on a real video.
#
# The original video is around 8 minutes long, so a short section will be tested first before processing the complete video.

# %%
# Import YOLO and load the final trained model

from ultralytics import YOLO

model = YOLO("runs/detect/helmet_100_epochs/weights/best.pt")

# %%
# Run helmet detection on the test video

results = model.predict(
    source="../data/video/testing_full_video.mp4",
    imgsz=640,
    conf=0.25,
    save=True)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/465) D:\ML\realtime-helmet-detection\notebooks\..\data\video\testing_full_video.mp4: 640x384 1 Helmet, 147.5ms
# video 1/1 (frame 2/465) D:\ML\realtime-helmet-detection\notebooks\..\data\video\testing_full_video.mp4: 640x384 1 Helmet, 63.3ms
# video 1/1 (frame 3/465) D:\ML\realtime-helmet-detection\notebooks\..\data\video\testing_full_video.mp4: 640x384 1 Helmet, 43.8ms
# ...
